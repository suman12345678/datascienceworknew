# %% [markdown]
# ## Static html

# %%
#test static html
import os
os.chdir(r'C:\Users\suman12345678\Downloads\lsa')  #chrome drive downloaded file match with chrome version
from selenium import webdriver
link='https://www.google.com/'
browser = webdriver.Chrome(executable_path = 'C:/Users/suman12345678/chromedriver')
browser.get(link)
try:
    ele=browser.find_element_by_link_text('Images')
    browser.implicitly_wait(5)
    ele.click()
except Exception as e:
    print('error',e)
    
#back to previous page
browser.back()
# browser.forward()
#close
# browser.close()
# Out:
# content

# %%
##

# %%
# import os
# os.chdir(r'C:\Users\suman12345678\Downloads\lsa')  #chrome drive downloaded file match with chrome version
# from selenium import webdriver
# link='https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US'
# browser = webdriver.Chrome(executable_path = 'C:/Users/suman12345678/chromedriver')
# browser.get(link)
# #http://pythonfordatabuggers.blogspot.com/2020/04/automatically-open-and-do-some-actions.html

# # Getting the tag for submit button                      
# # driver.find_element_by_class_name("login__form_action_container").click()

# # to click on network button
# try:
# #     browser.find_element_by_id("(856) 296-8532").click() 
# #     content=browser.find_element_by_class_name('jru90 wllRo')
# #     content=browser.find_element_by_css_selector('p.content')
#     print('content')
# #     content.click()
# except Exception as e:
#     print('error',e)
# #     browser.close()
# Out:
# content

# %% [markdown]
# ## Set cust_id

# %%
import codecs
import pyautogui
import os
from selenium import webdriver
from lxml import html
import os
import time
import requests
from pydub import AudioSegment


os.chdir(r'C:\Users\suman12345678\Downloads\lsa')  #chrome drive downloaded file match with chrome version

link='https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US'

browser = webdriver.Chrome(executable_path = 'C:/Users/suman12345678/chromedriver')
browser.get(link)

# browser.page_source
a=browser.find_elements_by_class_name("zRhise")  # this gives all phone no's and other 5 fields; dynamic

# %%
# browser
# a=browser.find_elements_by_class_name("zRhise")  # this gives all phone no's and other 5 fields; dynamic

# %%
# int(len(a)/5)
# from lxml import html
len(a)
# Out:
# 140

# %% [markdown]
# ## Loop through page

# %%
#working
print('current b',browser.current_url)  # always current browser
# os.chdir(r'C:\Users\suman12345678\Downloads\lsa\test')  #chrome drive downloaded file match with chrome version

def one_page():
    for i in range(0,int(len(a)/5)):
        #for each phone number
        a[i*5].clear
    #     print('current b',browser.current_url)
        browser.implicitly_wait(10)
        time.sleep(5)

        loop=True
        while(loop):
            try:
                a[i*5].click() # first item, if doesnot work try again
                loop=False
            except ElementClickInterceptedException:
                print(' error element click')
                continue


        b=browser.find_elements_by_class_name("rMhzce.DPvwYc")
        print(b)

        for j in b:
            #for each mp3
    #         j.clear
            print('current b',browser.current_url)
            browser.implicitly_wait(10)
            j.click() # first item
            print('click')  # there are 2 same link only one time need to click , take first one
            break

        browser.implicitly_wait(2000)
        time.sleep(5)
        complete_name = 'Lead.html' #os.path.join(save_path, file_name)
        file_object = codecs.open(complete_name, "w", "utf-8")
        htmlpage = browser.page_source
        print('writing....')
        file_object.write(htmlpage)
        file_object.close()

        #Now Lead.html loaded in folder now run python script
        print(os.curdir)
        in_file = "Lead.html"
        #create folder if doesnot exist
        download_folder = "download\\1111\\June"
        if not os.path.exists(download_folder):
            print('create folder')
            os.makedirs(download_folder)

    #     while True:
    #         print("Checking for file")
        if os.path.exists(in_file):
            print('ssss')
            with open(in_file, "rb") as f:
                result = f.read()
            tree = html.fromstring(result)
            print('tree',tree)
            try:
                audio_tag=tree.xpath("//audio/source")[0]
                #print(audio_tag)
                src = audio_tag.get('src')
                print("link found: "+src)
                split = src.split('?')
                url = split[0]
                params = dict()
                for param in split[1].split('&'):
                    s = param.split('=')
                    params[s[0]]=s[1]
                #print(params)
                split = url.split('/')
                filename = split[len(split)-1]
                print("Downloading: "+filename)
                r = requests.get(url = url, params = params, allow_redirects=True)
            #get recieved date
                all_divs = tree.xpath('//div')
                for a_div in all_divs:
                    if a_div.text is not None and "Received on " in a_div.text:
                        date_st = a_div.text.replace("Received on ","")
                        continue
                import datetime
                date_suffix = datetime.datetime.strftime(
                    datetime.datetime.strptime(date_st, '%b %d, %Y at %H:%M %p.'),"%m-%d-%Y_%H%M")
                download_to = download_folder+"/"+filename
                download_to = download_to.replace(".mp3","_"+date_suffix+".mp3")
                with open(download_to, 'wb') as f:
                    f.write(r.content)
                print("Downloaded to: "+download_to)
                song = AudioSegment.from_mp3(download_to)
                download_to_flac = download_to.replace(".mp3",".flac")
                song.export(download_to_flac,format = "flac")
                backup_folder = download_folder+"/"+filename.replace(".mp3","")
                if not os.path.exists(backup_folder):
                    print("Creating bacup folder: "+backup_folder)
                    os.makedirs(backup_folder)
                backup_file = backup_folder+"/"+in_file
                print("Moving HTML to backup: "+backup_file)
                os.rename(in_file,backup_file)
            except Exception as e:
                print('error*****',e)
        else:
            print("File not found, sleeping")
            time.sleep(5)

        time.sleep(5)


        #Now goback to previus page
        browser.back()

#call all pages
one_page()  
c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
while(len(c)>1)
    c[1].click()
    one_page()  
    c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
print('end')
# Out:
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-42-4d960f30219f> in <module>
#      10     browser.implicitly_wait(10)
#      11     time.sleep(5)
# ---> 12     a[i*5].click() # first item
#      13
#      14     b=browser.find_elements_by_class_name("rMhzce.DPvwYc")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# ...

# %% [markdown]
# ## Try

# %%
from selenium.common.exceptions import ElementClickInterceptedException
#working
print('current b',browser.current_url)  # always current browser
# os.chdir(r'C:\Users\suman12345678\Downloads\lsa\test')  #chrome drive downloaded file match with chrome version


def one_page():
    for i in range(0,int(len(a)/5)):
        #for each phone number
    #     a[i*5].clear
    #     print('current b',browser.current_url)
        browser.implicitly_wait(10)
    #     time.sleep(5)

        loop=True
        while(loop):
            try:
                a[i*5].click() # first item, if doesnot work try again
                loop=False
            except ElementClickInterceptedException:
                print(' error element click')
                continue

        b=browser.find_elements_by_class_name("rMhzce.DPvwYc")
        print(browser.current_url)

        for j in b:
            #for each mp3
    #         j.clear
            print('current b',browser.current_url)
            browser.implicitly_wait(10)
            j.click() # first item
            print('click')  # there are 2 same link only one time need to click , take first one
            break

        browser.implicitly_wait(2000)
        time.sleep(5)
        complete_name = 'Lead.html' #os.path.join(save_path, file_name)
        file_object = codecs.open(complete_name, "w", "utf-8")
        htmlpage = browser.page_source
        print('writing....')
        file_object.write(htmlpage)
        file_object.close() 



        #Now goback to previus page
        browser.back()

one_page()     
c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
if len(c)>1:
    c[1].click()
    one_page()  
    c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
    if len(c)>1:
        c[1].click()
        one_page()     
    else:
        print('end')
        c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
        if len(c)>1:
            c[1].click()
             one_page()     
        else:
            print('end')

else:
    print('end')
# Out:
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# [<selenium.webdriver.remote.webelement.WebElement (session="21ae6754835be4c061e254e544cc8765", element="f5901be9-4f03-423b-af73-db4d05853167")>, <selenium.webdriver.remote.webelement.WebElement (session="21ae6754835be4c061e254e544cc8765", element="c1c06cd3-9e76-474d-85fe-e7b9f28b87a8")>]
# current b https://adwords.google.com/localservices/lead?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&lid=3102701649&hl=en&gl=US
# click
# writing....
#  error element click
# [<selenium.webdriver.remote.webelement.WebElement (session="21ae6754835be4c061e254e544cc8765", element="519d3c20-85bd-4a04-9162-8cc769dbb93b")>, <selenium.webdriver.remote.webelement.WebElement (session="21ae6754835be4c061e254e544cc8765", element="17bf9dbb-830f-42c5-a155-23ec13b48d2d")>]
# ...

# %%
c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
while(len(c)>1):
    print('next page')
    c[1].click()
    c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")
print('end')
# Out:
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# next page
# ...

# %%
# c=browser.find_elements_by_class_name("utnMJd")
# c=browser.find_elements_by_class_name("a73E9b")
# c=browser.find_elements_by_class_name("QZAqyd")
# c=browser.find_elements_by_class_name("UwdJ1c")
# c=browser.find_elements_by_class_name("ZQsUQe")
c=browser.find_elements_by_class_name("DPvwYc.fnrFqd")


# c=browser.find_elements_by_class_name("VgjuZe")
print(len(c))
# c[1].click()
# Out:
# 2

# %%
# # a
# browser.current_url

# from pywebcopy import save_webpage
# download_folder = ''    
# kwargs = {'bypass_robots': True, 'project_name': 'Lead'}
# # save_webpage(browser.current_url, download_folder, **kwargs)

# %%
#working
print('current b',browser.current_url)  # always current browser
os.chdir(r'C:\Users\suman12345678\Downloads\lsa\test')  #chrome drive downloaded file match with chrome version
import codecs
import pyautogui

for i in a:
    i.clear
    print('current b',browser.current_url)
    browser.implicitly_wait(10)
    i.click() # first item
    
#     print(browser)
    second_label=browser.current_url
#     b=browser.find_elements_by_class_name("JJ1lH")
#     print(b)
#     b=browser.find_elements_by_class_name("Hn5RCf")
#     print(b)
#     b=browser.find_elements_by_class_name("JU813c")  #blank
#     print(b)
#     b=browser.find_elements_by_class_name("cQClf")
#     print(b)
#     b=browser.find_elements_by_class_name("Lhk6yf")
#     print(b)
#     b=browser.find_elements_by_class_name("JR5Wcf")
#     print(b)
#     b=browser.find_elements_by_class_name("WttEje")
#     print(b)
#     b=browser.find_elements_by_class_name("KFvVmd")  #sometimes ElementNotInteractableException, just try again
#     print(b)
#     b=browser.find_elements_by_class_name("SVYu7c")
#     print(b)
#     b=browser.find_elements_by_class_name("jkfOVd")
#     print(b)
#     b=browser.find_elements_by_class_name("qkJPbb")
#     print(b)
    
    b=browser.find_elements_by_class_name("rMhzce.DPvwYc")
    print(b)
    
    
#     with open('Lead.html', 'w') as f:
#         f.write(browser.page_source)
        
#     complete_name = 'Lead.html' #os.path.join(save_path, file_name)
#     file_object = codecs.open(complete_name, "w", "utf-8")
#     html = browser.page_source
#     file_object.write(html)
#     file_object.close()
#     browser.close()


#     page = browser.page_source
#     file_ = open('Lead.html', 'w')
#     file_.write(page)
#     file_.close()    
    
    
#     print(b)
#     b=browser.find_element_by_link_text('SHOW RECORDING')
#     b=browser.find_element_by_link_text("SHOW RECORDING")
#     print(b)
#     b.click()

    for j in b:
#         j.clear
        print('current b',browser.current_url)
        browser.implicitly_wait(10)
        j.click() # first item
        print('click')  # there are 2 same link only one time need to click
        break
        
    browser.implicitly_wait(2000)
    time.sleep(5)
    complete_name = 'Lead.html' #os.path.join(save_path, file_name)
    file_object = codecs.open(complete_name, "w", "utf-8")
    html = browser.page_source
    print('writing....')
    file_object.write(html)
    file_object.close()

#     from selenium.webdriver.common.action_chains import ActionChains
#     from selenium.webdriver.common.keys import Keys

#     save_me = ActionChains(browser).key_down(Keys.CONTROL)\
#          .key_down('s').key_up(Keys.CONTROL).key_up('s')
#     save_me.perform()

#     from pywebcopy import save_webpage
#     download_folder = ''    
# #     kwargs = {'bypass_robots': True, 'project_name': 'recognisable-name'}
#     save_webpage(browser.current_url, download_folder, **kwargs)

#     browser.implicitly_wait(10)        
#     pyautogui.hotkey('ctrl', 's')
#     time.sleep(1)
#     pyautogui.typewrite('Lead.html')
#     pyautogui.hotkey('enter')

    #save file as Lead
#     pyautogui.keyDown("ctrl")
#     pyautogui.press("s")
#     pyautogui.keyUp("ctrl")
    
    
    break
    
    
#after expand
#https://adwords.google.com/localservices/lead?cid=8458624334&bid=2516381167&pid=2520017630&mcid=9172095800&euid=7247586698&lid=8416087777&hl=en&gl=US
#https://adwords.google.com/localservices/lead?cid=8458624334&bid=2516381167&pid=2520017630&mcid=9172095800&euid=7247586698&lid=8416087777&hl=en&gl=US
# Out:
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# [<selenium.webdriver.remote.webelement.WebElement (session="7fb0ad33cf4f56a398b217fe398db424", element="7f66e9f2-30f3-4ef1-beb5-48b8ccc9c683")>, <selenium.webdriver.remote.webelement.WebElement (session="7fb0ad33cf4f56a398b217fe398db424", element="2d2e1aca-9ba0-494b-a356-8bda1011ffd6")>]
# current b https://adwords.google.com/localservices/lead?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&lid=3102701649&hl=en&gl=US
# click
# writing....

# %%
#working
print('current b',browser.current_url)  # always current browser
os.chdir(r'C:\Users\suman12345678\Downloads\lsa\test')  #chrome drive downloaded file match with chrome version
import codecs
import pyautogui
import time

for i in a:
    i.clear
    print('current b',browser.current_url)
    browser.implicitly_wait(10)
    i.click() # first item
    
    b=browser.find_elements_by_class_name("rMhzce.DPvwYc")
    print(b)

    for j in b:
#         j.clear
        browser.implicitly_wait(10)
        j.click() # first item
        print('click')  # there are 2 same link only one time need to click
        break

#     browser.implicitly_wait(10)
#     pyautogui.hotkey('ctrl', 's')
#     time.sleep(1)
#     pyautogui.typewrite('Lead.html')
#     pyautogui.hotkey('enter')

#     complete_name = 'Lead.html' #os.path.join(save_path, file_name)
#     file_object = codecs.open(complete_name, "w", "utf-8")
#     html = browser.page_source
#     file_object.write(html)
#     file_object.close()

    from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
    import ahk
    ahk.start()
    ahk.ready()
    ahk.execute("Send,^s")
    ahk.execute("WinWaitActive, Save As,,2")
    ahk.execute("WinActivate, Save As")
    ahk.execute("Send, Lead.html")
    ahk.execute("Send, {Enter}")


    break
# Out:
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# current b https://adwords.google.com/localservices/reports?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&hl=en&gl=US
# [<selenium.webdriver.remote.webelement.WebElement (session="68e8744956773dce0f2e272f056de364", element="4081ea7e-03f0-4554-abd0-6dcdb74d8267")>, <selenium.webdriver.remote.webelement.WebElement (session="68e8744956773dce0f2e272f056de364", element="29e3a903-39a2-4f7f-b389-fc4be2fb972e")>]
# click
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2521d094b972> in <module>
#      36     from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
#      37     import ahk
# ---> 38     ahk.start()
#      39     ahk.ready()
#      40     ahk.execute("Send,^s")
#
# ...

# %%
ahk.

# %%
# text saves html
from lxml import html
os.chdir(r'C:\Users\suman12345678\Downloads\lsa')  #chrome drive downloaded file match with chrome version
import os
import time
import requests
from pydub import AudioSegment
in_file = "Lead.html"
if os.path.exists(in_file):
    with open(in_file, "rb") as f:
        result = f.read()
    print(result)    
    tree = html.fromstring(result)
    print('tree',tree)
    audio_tag=tree.xpath("//audio/source")[0]
    print(tree)
# Out:
# b'<html lang="en" dir="ltr"><head><script async="" src="https://www.google-analytics.com/analytics.js" nonce=""></script><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.yyhByYeMTAc.O/m=gapi_iframes,googleapis_client,plusone/rt=j/sv=1/d=1/ed=1/am=AAY/rs=AHpOoo-O470EQdZ-4tpWpppyTQmeOEUv-g/cb=gapi.loaded_0" nonce="" async=""></script><base href="https://adwords.google.com/"><meta name="referrer" content="origin"><meta name="viewport" content="initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="application-name" content="Home Services"><meta name="apple-mobile-web-app-title" content="Home Services"><meta name="apple-mobile-web-app-status-bar-style" content="black"><meta name="msapplication-tap-highlight" content="no"><link rel="manifest" crossorigin="use-credentials" href="_/GhsUi/manifest.json"><link rel="home" href="/?lfhs=2"><lin
# ...

# %%
# browser.page_source

# %%
# text saves html
in_file = "Leadgood.html"
if os.path.exists(in_file):
    with open(in_file, "rb") as f:
        result = f.read()
    print(result)    
    tree = html.fromstring(result)
    print('tree',tree)
    audio_tag=tree.xpath("//audio/source")[0]
    print(tree)
# Out:
# b'<!DOCTYPE html>\n<!-- saved from url=(0149)https://adwords.google.com/localservices/lead?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&lid=3102701649&hl=en&gl=US -->\n<html lang="en" dir="ltr"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><script async="" src="./Leadgood_files/analytics.js.download" nonce=""></script><script src="./Leadgood_files/cb=gapi.loaded_0" nonce="" async=""></script><!--<base href="https://adwords.google.com/">--><base href="."><meta name="referrer" content="origin"><meta name="viewport" content="initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="application-name" content="Home Services"><meta name="apple-mobile-web-app-title" content="Home Services"><meta name="apple-mobile-web-app-status-bar-style" content="black"><meta name="msapplication-tap-highlight" content="no">
# ...

# %%
tree.xpath("//audio/source")[0]
# Out:
# <Element source at 0xf9a13ae1d8>

# %%
https://adwords.google.com/localservices/lead?cid=5764196044&bid=2517892389&pid=2521937883&mcid=9172095800&euid=7247586698&lid=3102701649&hl=en&gl=US

# %%
# browser.page_source
j.id
browser.page_source
tree=html.fromstring(browser.page_source)
tree
tree.xpath("//audio/source")[0]
# Out:
# <Element source at 0xbcfabca228>

# %%
# browser.page_source
browser.find_elements_by_class_name("jru90 wllRo")
browser.find_elements_by_class_name("XgRaPc AB6Eee")
browser.find_element_by_tag_name('div')
elm=browser.find_element_by_link_text("(856) 676-6137")
browser.implicitly_wait(5)
elm.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-61-d55acfeb9fe7> in <module>
#       3 browser.find_elements_by_class_name("XgRaPc AB6Eee")
#       4 browser.find_element_by_tag_name('div')
# ----> 5 elm=browser.find_element_by_link_text("(856) 676-6137")
#       6 browser.implicitly_wait(5)
#       7 elm.click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
browser.find_elements_by_class_name("jru90 wllRo")
# browser.find_element_by_css_selector('div.jru90 wllRo')
# browser.find_elements_by_css_selector("div.classname jru90 wllRo")
browser.find_elements_by_class_name("jru90 wllRo")
browser.find_element_by_link_text('(856) 676-6137')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-52-a09fc8b886f6> in <module>
#       3 # browser.find_elements_by_css_selector("div.classname jru90 wllRo")
#       4 browser.find_elements_by_class_name("jru90 wllRo")
# ----> 5 browser.find_element_by_link_text('(856) 676-6137')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
# browser.find_element_by_class_name('jru90 wllRo')
# Out:
# 'https://adwords.google.com/localservices/reports?cid=8458624334&bid=2516381167&pid=2520017630&mcid=9172095800&euid=7247586698&hl=en&gl=US'

# %%
from lxml import html
os.chdir(r'C:\Users\suman12345678\Downloads\lsa')  #chrome drive downloaded file match with chrome version

import os
import time
import requests
from pydub import AudioSegment
print(os.curdir)
in_file = "Lead.html"
download_folder = "download\\1111\\June"
if not os.path.exists(download_folder):
    print('create folder')
    os.makedirs(download_folder)
    
while True:
    print("Checking for file")
    if os.path.exists(in_file):
        print('ssss')
        with open(in_file, "rb") as f:
            result = f.read()
        tree = html.fromstring(result)
        print('tree',tree)
        try:
            audio_tag=tree.xpath("//audio/source")[0]
            #print(audio_tag)
            src = audio_tag.get('src')
            print("link found: "+src)
            split = src.split('?')
            url = split[0]
            params = dict()
            for param in split[1].split('&'):
                s = param.split('=')
                params[s[0]]=s[1]
            #print(params)
            split = url.split('/')
            filename = split[len(split)-1]
            print("Downloading: "+filename)
            r = requests.get(url = url, params = params, allow_redirects=True)
        #get recieved date
            all_divs = tree.xpath('//div')
            for a_div in all_divs:
                if a_div.text is not None and "Received on " in a_div.text:
                    date_st = a_div.text.replace("Received on ","")
                    continue
            import datetime
            date_suffix = datetime.datetime.strftime(
                datetime.datetime.strptime(date_st, '%b %d, %Y at %H:%M %p.'),"%m-%d-%Y_%H%M")
            download_to = download_folder+"/"+filename
            download_to = download_to.replace(".mp3","_"+date_suffix+".mp3")
            with open(download_to, 'wb') as f:
                f.write(r.content)
            print("Downloaded to: "+download_to)
            song = AudioSegment.from_mp3(download_to)
            download_to_flac = download_to.replace(".mp3",".flac")
            song.export(download_to_flac,format = "flac")
            backup_folder = download_folder+"/"+filename.replace(".mp3","")
            if not os.path.exists(backup_folder):
                print("Creating bacup folder: "+backup_folder)
                os.makedirs(backup_folder)
            backup_file = backup_folder+"/"+in_file
            print("Moving HTML to backup: "+backup_file)
            os.rename(in_file,backup_file)
        except Exception as e:
            print('error*****',e)
    else:
        print("File not found, sleeping")
        time.sleep(5)
# Out:
# .
# Checking for file
# ssss
# tree <Element html at 0xd44e23b048>
# link found: https://storage.googleapis.com/ghs-phone-recordings-prod/rkedyainxwueusprpytiqlghdrraiceldtryzpla.mp3?GoogleAccessId=101618223269538450093&Expires=1593235795&Signature=H4VVuRSZCFVoc73nnKlZaRH%2BBgj1khOkX7nXRiIocQIzM04dCWW5/XL9PJ3d1O2BuSMQQCdPI6BPAT0rGVkmWrMqF6cRS11YBITdItEMylbx8VHUVzuPJ9MwnHbXs%2BOENxFOT2S/8pOih3Z0wKA7hRl9etkVslZTgn7hbdGi2mybrOB6q2jzJaRVLcWRXleIPsh77UUvaVtS7SlSnxiEF4YdRY98t%2BSLjjP2aOx3Aqwanyfa959hYIFr5bd%2BZbZ9SMinAhl0EgTllQtg4gZEnCQ1w0Bt%2BSnPXsmw9L0sjtKyBtGqSGxdYq57qLWVLXLqoUuZ794mdk6Rwj7Pltv9jg%3D%3D
# Downloading: rkedyainxwueusprpytiqlghdrraiceldtryzpla.mp3
# Downloaded to: download\1111\June/rkedyainxwueusprpytiqlghdrraiceldtryzpla_05-31-2020_0124.mp3
# Creating bacup folder: download\1111\June/rkedyainxwueusprpytiqlghdrraiceldtryzpla
# Moving HTML to backup: download\1111\June/rkedyainxwueusprpytiqlghdrraiceldtryzpla/Lead.html
# Checking for file
# File not found, sleeping
# ...

# %%
os.chdir(r'C:\Users\suman12345678\Downloads\lsa')

in_file = "Lead.html"
download_folder = "download/2/APRIL"

print("Checking for file")
if os.path.exists(in_file):
    print('hi')
# Out:
# Checking for file

# %%
os.chdir(r'C:\Users\suman12345678\Downloads\lsa')
os.listdir()
# Out:
# ['download', 'downloader.py', 'downloaderold.py']
